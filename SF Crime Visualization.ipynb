# %%
require(ggplot2)

# read San Francisco Summer 2014 dataset from github
print("Reading data...")
sf = read.csv("https://github.com/uwescience/datasci_course_materials/raw/master/assignment6/sanfrancisco_incidents_summer_2014.csv")
print("Done")
# Out:
# [1] "Reading data..."
# [1] "Done"

# %%
# plot number of crimes by district
p = ggplot(sf, aes(x=PdDistrict))
p + geom_bar(aes(fill=DayOfWeek))
# Out:
# plot without title
